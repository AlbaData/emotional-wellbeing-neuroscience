# %% [markdown]
# # 📊 Exploratory Data Analysis – Emotional Wellbeing Dataset
#
# This project explores the relationship between lifestyle habits and emotional wellbeing based on neuroscience-informed variables.
#
# We begin with an overview and data quality checks.

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("dataset_bienestar_emocional.csv")
df.head()
# Out:
#    ID  Edad  Género  Horas_sueño  Ejercicio_semanal Alimentación_saludable  \
# 0   1    56   Mujer          5.4                  5                A veces
# 1   2    46  Hombre          6.9                  5                Siempre
# 2   3    32   Mujer          4.6                  1                A veces
# 3   4    60   Mujer          5.4                  3                Siempre
# 4   5    25   Mujer          8.9                  6                A veces
#
#   Meditación Autocuidado  Uso_pantallas_diario Hobbies_pasion  \
# 0      Nunca       Medio                   5.1         Música
# 1      Nunca        Bajo                   5.2        Pintura
# 2      Nunca        Alto                   6.2        Pintura
# 3  Frecuente       Medio                   3.0        Deporte
# 4      Nunca       Medio                   4.5        Lectura
#
#   Bienestar_emocional
# 0               Medio
# 1               Medio
# 2               Medio
# 3                Alto
# 4                Bajo

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      200 non-null    int64
#  1   Edad                    200 non-null    int64
#  2   Género                  200 non-null    object
#  3   Horas_sueño             200 non-null    float64
#  4   Ejercicio_semanal       200 non-null    int64
#  5   Alimentación_saludable  200 non-null    object
#  6   Meditación              200 non-null    object
#  7   Autocuidado             200 non-null    object
#  8   Uso_pantallas_diario    200 non-null    float64
#  9   Hobbies_pasion          200 non-null    object
#  10  Bienestar_emocional     200 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 17.3+ KB

# %%
# Unique values per column
df.nunique()
# Out:
# ID                        200
# Edad                       46
# Género                      3
# Horas_sueño                53
# Ejercicio_semanal           7
# Alimentación_saludable      3
# Meditación                  3
# Autocuidado                 3
# Uso_pantallas_diario       76
# Hobbies_pasion              6
# Bienestar_emocional         3
# dtype: int64

# %%
# Null values
df.isnull().sum()
# Out:
# ID                        0
# Edad                      0
# Género                    0
# Horas_sueño               0
# Ejercicio_semanal         0
# Alimentación_saludable    0
# Meditación                0
# Autocuidado               0
# Uso_pantallas_diario      0
# Hobbies_pasion            0
# Bienestar_emocional       0
# dtype: int64

# %%
# Summary statistics
df.describe()
# Out:
#                ID        Edad  Horas_sueño  Ejercicio_semanal  \
# count  200.000000  200.000000   200.000000         200.000000
# mean   100.500000   41.570000     7.117000           3.120000
# std     57.879185   13.715527     1.189363           1.991338
# min      1.000000   18.000000     4.100000           0.000000
# 25%     50.750000   30.000000     6.400000           1.000000
# 50%    100.500000   42.000000     7.100000           3.000000
# 75%    150.250000   54.000000     8.000000           5.000000
# max    200.000000   64.000000     9.800000           6.000000
#
#        Uso_pantallas_diario
# count            200.000000
# mean               5.133500
# std                2.047778
# min               -0.800000
# 25%                3.700000
# 50%                5.200000
# 75%                6.500000
# max                9.900000

# %% [markdown]
# ## ✅ Summary of Findings
#
# - The dataset contains 200 entries and 11 variables.
# - No missing values were found.
# - Numerical variables include age, sleep hours, screen time, and exercise frequency.
# - One unrealistic value (negative screen time) was found and should be corrected in data cleaning.
